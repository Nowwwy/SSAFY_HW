# %% [markdown]
# # 3205

# %% [markdown]
# # 3206

# %% [markdown]
# # 3207

# %% [markdown]
# # 3208

# %% [markdown]
# # 3209

# %% [markdown]
# # 3010

# %% [markdown]
# # 3011

# %% [markdown]
# # 3012

# %% [markdown]
# # 2640

# %% [markdown]
# # 2619
